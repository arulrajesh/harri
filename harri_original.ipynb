# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import subprocess
import os
import pandas as pd
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException,StaleElementReferenceException, TimeoutException
import time
driver = webdriver.Chrome(executable_path='chromedriver\chromedriver.exe')
driver.maximize_window()
driver.get('http://harristaging.com/user/login')
wait = WebDriverWait(driver, 60)

# %%
def harri_login(hwait, uname, upass):
    uname = hwait.until(EC.element_to_be_clickable((By.NAME, 'username')))
    passw = hwait.until(EC.element_to_be_clickable((By.NAME, 'password')))
    login = hwait.until(EC.presence_of_element_located((By.XPATH, "//*[@id='harriApp']/div[1]/ui-view/registration-login-container/div[2]/div/div[2]/div[7]/button")))
    uname.send_keys(uemail)
    passw.send_keys(upass)
    login.click()

# %%
class AnyEc:
    """ Use with WebDriverWait to combine expected_conditions
        in an OR.
    """

    def __init__(self, *args):
        self.ecs = args

    def __call__(self, driver):
        for fn in self.ecs:
            try:
                res = fn(driver)
                if res:
                    return res
                    # Or return res if you need the element found
            except:
                pass

# %%
# click "Got it" on the Create your own dashboard view page.
def got_it():
    try:
        element = wait.until(EC.element_to_be_clickable(
            (By.XPATH, "//*[@id='top']/div/nav/div/div/div[4]/a[4]")))
        element.click()
    finally:
        pass

# %%
# Get into the dashboard by clicking on the first parent in the list
def goto_dashboard():
    try:
        element = wait.until(EC.element_to_be_clickable((By.XPATH, "//li[contains(@class,'brand-navigation')]")))
        element.click()
        searchbar = wait.until(EC.element_to_be_clickable((By.XPATH, "//div[contains(@class,'locations-list-wrapper')][2]//div[contains(@class,'brand-item')][1]")))
        searchbar.click()
    finally:
        pass

# %%
# once at dashboard page. Go to My Team
def goto_myteam():
    try:
        element = wait.until(EC.element_to_be_clickable(
            (By.XPATH, "//*[@id='header-links-nav']//a[contains(.,'My Team')]")))
        element.click()
    finally:
        pass

# %%
# click forecasting
def goto_forecasting():
    try:
        element = wait.until(EC.element_to_be_clickable((By.XPATH, "//*[@id='header-links-nav']//li[contains(.,'Forecasting')]/div/button")))

        while (element.get_attribute("innerText")) != "Forecasting":

            element = wait.until(EC.element_to_be_clickable((By.XPATH, "//*[@id='header-links-nav']//li[contains(.,'Forecasting')]/div/button")))

        element.click()
        print(element.get_attribute("innerText"))  # should be Forecasting
    except ElementClickInterceptedException:
        click_ignore()
    finally:
        pass

# %%
def goto_historicaldata():
    try:  # click the Historical Data
        element = wait.until(EC.element_to_be_clickable(
            (By.XPATH, "//*[@id='header-links-nav']//a[contains(.,'Historical Data')]")))
        element.click()
    finally:
        pass

# %%
def upload_modal():
    try:  # click the "Upload Historical data" popup window
        element = wait.until(EC.element_to_be_clickable(
            (By.XPATH, "//*[@id='manage-template-modal']/div/div/div[1]/h4/span")))
        print(element.get_attribute("innerText"))  # should be modal window
        element.click()
    finally:
        pass

# %%
def click_uploadhistoricaldata(attempts=0):
    attempts += 1
    try:  # check if the upload button is pressed otherwise click on the
        wait.until(EC.invisibility_of_element_located(
            (By.XPATH, "//*[@id='manage-template-modal']/div/div")))
        element = wait.until(EC.element_to_be_clickable((By.XPATH, "//*[@id='upload_data']/a")))
        element.click()
    except ElementClickInterceptedException:
        click_ignore()
        click_uploadhistoricaldata(attempts)
    except StaleElementReferenceException:
        click_uploadhistoricaldata(attempts)
    except TimeoutException:
        attempts = 100        
    finally:
        if attempts>2:print(f"attempts: {attempts}'\n'")
        return attempts

# %%
def hsearch(clientID, clickit=True):
    try:  # click somewhere on the page
        element_s = wait.until(EC.element_to_be_clickable(
            (By.XPATH, "//*[@id='harriApp']/div[1]/div/div[3]/forecasts-historical-data-component/div/div[1]/div[1]")))
        element_s.click()
    finally:
        pass

    try:  # click on the top right search
        element_s = wait.until(EC.element_to_be_clickable(
            (By.XPATH, "//*[@id='harriApp']/div[1]/div/div[1]/div/div[1]/div[3]/div/div/div/a/div/div[2]/div[1]")))
        element_s.click()
    finally:
        pass
    try:  # search for the site
        element = wait.until(EC.element_to_be_clickable(
            (By.XPATH, "//*[@id='harriApp']/div[1]/div/div[1]/div/div[1]/div[3]/div/div/div[2]/h-brands-list/div/div/div[1]/div/input")))
        element.send_keys(clientID)
    finally:
        pass
    if clickit:
        try:  # Click on the first search result
            time.sleep(1)
            element = wait.until(EC.element_to_be_clickable(
                (By.XPATH, "//h-brands-list//div[@class='locations-list-wrapper'][2]/div/div[2]")))
            # //h-brands-list/div/div/div[5]/div/div[2]/div/div[2]//div[@class='locations-list-wrapper'][2]/div
            element.click()
        finally:
            pass

        try:  # click on the top right search
            element_s = wait.until(EC.element_to_be_clickable(
                (By.XPATH, "//*[@id='harriApp']/div[1]/div/div[1]/div/div[1]/div[3]/div/div/div/a/div/div[2]/div[1]")))
            element_s.click()
        finally:
            pass
            # time.sleep(10)
    else:
        elems = driver.find_elements(
            By.XPATH, "//h-brands-list//div[@class='locations-list-wrapper'][2]//div[contains(@class,'brand-name')]")
        companies = ""
        for x in elems:
            companies += x.get_attribute('innerText')+'|'
        return companies[:-1], len(elems)

    #
    #    //*[@id="harriApp"]/div[1]/div/div[1]/div/div[1]/div[3]/div/div/div[2]/h-brands-list/div/div/div[5]/div/div[2]/div/div[2]

# %%
def click_upload():
    click_uploadhistoricaldata()
    try:
        element = wait.until(AnyEc(EC.element_to_be_clickable((By.XPATH, "//forecasts-historical-data-component//button[contains(.,'Upload')]")),EC.element_to_be_clickable((By.XPATH,"//div[contains(@class,'modal-footer')]//button[contains(.,'Ignore')]"))))
        if element.get_attribute('innerText') == 'Ignore':
            element.click()
            click_uploadhistoricaldata()
            element = wait.until(EC.element_to_be_clickable((By.XPATH, "//forecasts-historical-data-component//button[contains(.,'Upload')]")))
    except NoSuchElementException:
        click_uploadhistoricaldata()
        element = wait.until(EC.element_to_be_clickable(
            (By.XPATH, "//*[@id='harriApp']/div[1]/div/div[3]/forecasts-historical-data-component/div/div[1]/div[2]/button[2]")))
    finally:
        element.click()

# %%
def hbrowse(fpath):
    try:  # click the "Browse" popup window
        element = wait.until(EC.element_to_be_clickable(
            (By.XPATH, "//*[@id='manage-template-modal']/div/div/div[2]/div/div[3]/div[2]/button")))
        element.click()
    finally:
        pass
    time.sleep(1)
    subprocess.Popen(f'''fileupload/fileupload.exe "{fpath}"''')
    time.sleep(2)

# %%
def final_upload(upload=True):
    try:  # click the Upload button in the popup window
        if upload:
            element = wait.until(EC.element_to_be_clickable(
                (By.XPATH, "//*[@id='manage-template-modal']//button[contains(.,'Upload')]")))  # upload
        else:
            element = wait.until(EC.element_to_be_clickable(
                (By.XPATH, "//*[@id='manage-template-modal']//button[contains(.,'Cancel')]")))  # cancel
        element.click()
    except ElementClickInterceptedException:
        click_ignore()
        element.click()
    finally:
        pass

# %%
def click_ignore():
    try:
        ignore_btn = driver.find_element(By.XPATH, "//div[contains(@class,'modal-footer')]//button[contains(.,'Ignore')]")
        ignore_btn.click()
    except NoSuchElementException:
        pass
    finally:
        pass

# %%
def status_write():
    attempts = click_uploadhistoricaldata(0)
    status = "Took too Long. Attempts: "+ str(attempts)
    
    try:  # Locate the presence of the table after upload and find the status in the last row
        # //*[@id="upload_data"]/div/div/ng-transclude/upload-historical-data-component/div/div[2]/div[2]/table
        result = wait.until(AnyEc(EC.visibility_of_element_located((By.XPATH, "//*[@id='upload_data']/div/div/ng-transclude/upload-historical-data-component/div/div[2]/div[2]/table")), EC.visibility_of_element_located(
            (By.XPATH, "//div[contains(@class,'upload-historical-data-component')]//div[contains(.,'No uploaded files')]"))))
        if result.get_attribute('innerText') != 'No uploaded files':
            rows = driver.find_elements_by_xpath(
                "//*[@id='upload_data']/div/div/ng-transclude/upload-historical-data-component/div/div[2]/div[2]/table/tbody/tr")
            status = driver.find_element(
                By.XPATH, f"//*[@id='upload_data']/div/div/ng-transclude/upload-historical-data-component/div/div[2]/div[2]/table/tbody/tr[{len(rows)}]").get_attribute("innerText")
        else:
            status = 'No Uploaded Files'
    finally:
        print(status)
        return status

# %%
def validate_search():
    df = pd.DataFrame(os.listdir(
        'C:\\Users\\arulr\\harri\\historicals'), columns=['historicals'])
    clist = []
    nlist = []
    search_terms = []
    for row in df.itertuples():
        clientid = row.historicals[:-4]
        hsearch(clientid, False)
        elemtn = driver.find_elements(
            By.XPATH, "//div[contains(@class,'locations-list-wrapper')][2]//div[contains(@class,'brand-name')]")
        if len(elemtn) != 1:
            # try to split the file name and do a search for each
            sterms = clientid.split(' ')
            for x in sterms:
                companies, tin = hsearch(x.strip(), False)
                if tin == 1:
                    search_term = x
                    break
                else:
                    search_term = 'ZZZZZZZZZZZZ'
                    companies = 'ZZZZZZZZZZZZZZZZ'

        else:
            companies = elemtn[0].get_attribute("innerText")
            search_term = clientid
        search_terms.append(search_term)
        clist.append(companies)
        nlist.append(len(elemtn))
    df['companies'] = clist
    df['#results'] = nlist
    df['clientid'] = search_terms
    df.to_csv('list.csv', index=False)

# %%
uemail = 'STAGING_Grant.Read@demipower.com'
upass = 'House123!'
harri_login(wait, uemail, upass)
got_it()
goto_dashboard()
got_it()
goto_myteam()
goto_forecasting()
goto_historicaldata()
try:
    click_ignore()
finally:
    pass
#validate_search()

# %%
df = pd.read_csv("list.csv")
df2 = df.copy()
statuss = []
for row in df.itertuples():
    clientid, fname,upload = row.clientid, f"{os.getcwd()}\historicals\{row.historicals}",row.upload
    if upload:
        click_uploadhistoricaldata()
        hsearch(clientid)
        print(f'"{fname}"        {clientid}')
        click_upload()
        hbrowse(fname)
        final_upload()
        statuss.append(status_write())
#       statuss.append("Took too long")
df3 = pd.DataFrame(statuss,columns=['stat'])

df2[['date','uploadedby','filename','status']]=df3['stat'].str.split('\t',expand=True)

df2.to_csv('output.csv')
# Out:
# "c:\Users\arulr\harri\historicals\aberdare.csv"        aberdare
# Jun 28, 2022	Grant Read	aberdare.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\alperton.csv"        alperton
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	alperton.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\apex corner.csv"        apex corner
# Jun 28, 2022	Grant Read	apex corner.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\archway.csv"        archway
# Jun 28, 2022	Grant Read	archway.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\ashby de-la-zouch.csv"        ashby de-la-zouch
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	ashby de-la-zouch.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\aylesbury express.csv"        aylesbury express
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	aylesbury express.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\aylesbury retail park.csv"        aylesbury retail park
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	aylesbury retail park.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\baker street.csv"        baker street
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	baker street.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\barry.csv"        barry
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	barry.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\bath.csv"        bath
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	bath.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\beaconsfield services.csv"        beaconsfield
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	beaconsfield services.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\beeston.csv"        beeston
# Jun 28, 2022	Grant Read	beeston.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\blackwood.csv"        blackwood
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	blackwood.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\bridgend hernston.csv"        bridgend hernston
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	bridgend hernston.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\bridgend mcarthurglen.csv"        bridgend mcarthurglen
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	bridgend mcarthurglen.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\bristol bradley stoke.csv"        bristol bradley stoke
# Jun 28, 2022	Grant Read	bristol bradley stoke.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\bristol filton.csv"        bristol filton
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	bristol filton.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\bristol fishponds.csv"        bristol fishponds
# Jun 28, 2022	Grant Read	bristol fishponds.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\bristol union street.csv"        bristol union street
# Jun 28, 2022	Grant Read	bristol union street.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\burton.csv"        burton
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	burton.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\bury st edmunds.csv"        bury st edmunds
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	bury st edmunds.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\caerphilly.csv"        caerphilly
# Jun 28, 2022	Grant Read	caerphilly.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\camberwell.csv"        camberwell
# Jun 28, 2022	Grant Read	camberwell.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\cardiff excelsior road.csv"        cardiff excelsior road
# Jun 28, 2022	Grant Read	cardiff excelsior road.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\cardiff leckwith road.csv"        leckwith
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	cardiff leckwith road.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\cardiff newport road.csv"        cardiff newport road
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	cardiff newport road.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\cardiff queen street.csv"        cardiff queen street
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	cardiff queen street.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\cardiff st mary street.csv"        cardiff st mary street
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	cardiff st mary street.c	Uploaded successfully
# "c:\Users\arulr\harri\historicals\carmarthen.csv"        carmarthen
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	carmarthen.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\clapham.csv"        clapham
# Jun 28, 2022	Grant Read	clapham.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\coalville.csv"        coalville
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	coalville.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\cobham.csv"        cobham
# Jun 28, 2022	Grant Read	cobham.csv	Failed to upload
# "c:\Users\arulr\harri\historicals\colindale.csv"        colindale
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	colindale.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\corby.csv"        corby
# Jun 28, 2022	Grant Read	corby.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\cricklewood.csv"        cricklewood
# Jun 28, 2022	Grant Read	cricklewood.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\cross hands.csv"        cross hands
# Jun 28, 2022	Grant Read	cross hands.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\croydon addiscombe.csv"        croydon addiscombe
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	croydon addiscombe.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\croydon london road.csv"        croydon london road
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	croydon london road.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\cwmbran.csv"        cwmbran
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	cwmbran.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\derby services.csv"        derby services
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	derby services.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\dunstable express.csv"        dunstable express
# Jun 28, 2022	Grant Read	dunstable express.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\dunstable white lion.csv"        dunstable white lion
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	dunstable white lion.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\earls court.csv"        earls court
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	earls court.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\ebbw vale.csv"        ebbw vale
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	ebbw vale.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\edmonton.csv"        edmonton
# Jun 28, 2022	Grant Read	edmonton.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\finsbury park.csv"        finsbury park
# Jun 28, 2022	Grant Read	finsbury park.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\frome.csv"        frome
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	frome.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\glastonbury.csv"        glastonbury
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	glastonbury.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\gloucester road.csv"        gloucester road
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	gloucester road.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\greenford.csv"        greenford
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	greenford.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\harlesden.csv"        harlesden
# Jun 28, 2022	Grant Read	harlesden.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\harlow express.csv"        harlow express
# Jun 28, 2022	Grant Read	harlow express.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\harlow retail park.csv"        harlow retail park
# Jun 28, 2022	Grant Read	harlow retail park.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\harrow road.csv"        harrow road
# Jun 28, 2022	Grant Read	harrow road.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\harrow weald.csv"        harrow weald
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	harrow weald.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\heathrow.csv"        heathrow
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	heathrow.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\hendon.csv"        hendon
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	hendon.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\hornchurch.csv"        hornchurch
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	hornchurch.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\ipswich bury road.csv"        bury road
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	ipswich bury road.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\ipswich cardinal park.csv"        cardinal
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	ipswich cardinal park.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\ipswich felixstowe.csv"        felixstowe
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	ipswich felixstowe.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\ipswich martlesham.csv"        martlesham
# Jun 28, 2022	Grant Read	ipswich martlesham.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\kings lynn.csv"        kings lynn
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	kings lynn.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\leicester braunstone.csv"        leicester braunstone
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	leicester braunstone.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\leicester fosse park.csv"        fosse
# Jun 28, 2022	Grant Read	leicester fosse park.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\leicester hamilton.csv"        leicester hamilton
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	leicester hamilton.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\leicester high street.csv"        leicester high street
# Jun 28, 2022	Grant Read	leicester high street.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\leicester last straw.csv"        leicester last straw
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	leicester last straw.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\leicester services.csv"        leicester services
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	leicester services.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\leighton buzzard.csv"        leighton buzzard
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	leighton buzzard.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\llanelli.csv"        llanelli
# Jun 28, 2022	Grant Read	llanelli.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\long eaton.csv"        long eaton
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	long eaton.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\loughborough.csv"        loughborough
# Jun 28, 2022	Grant Read	loughborough.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\loughton.csv"        loughton
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	loughton.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\lowestoft.csv"        lowestoft
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	lowestoft.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\luton express.csv"        luton express
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	luton express.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\luton hatters way.csv"        luton hatters way
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	luton hatters way.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\luton mall.csv"        luton mall
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	luton mall.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\luton wigmore.csv"        luton wigmore
# Jun 28, 2022	Grant Read	luton wigmore.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\melton mowbray.csv"        melton mowbray
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	melton mowbray.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\merthyr tydfil.csv"        merthyr tydfil
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	merthyr tydfil.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\nantgarw.csv"        nantgarw
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	nantgarw.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\newport friars walk.csv"        newport friars walk
# Jun 28, 2022	Grant Read	newport friars walk.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\newport pullman.csv"        newport pullman
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	newport pullman.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\newport west.csv"        newport west
# Jun 28, 2022	Grant Read	newport west.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\norwich chapelfield.csv"        chapelfield
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	norwich chapelfield.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\norwich longwater.csv"        longwater
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	norwich longwater.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\norwich mile cross.csv"        mile
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	norwich mile cross.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\norwich sprowston.csv"        sprowston
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	norwich sprowston.csv	Failed to upload
# "c:\Users\arulr\harri\historicals\peterborough ashbourne road.csv"        ashbourne
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	peterborough ashbourne roa	Uploaded successfully
# "c:\Users\arulr\harri\historicals\peterborough london road.csv"        peterborough london road
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	peterborough london road.c	Uploaded successfully
# "c:\Users\arulr\harri\historicals\peterborough paston parkway.csv"        peterborough paston parkway
# Jun 28, 2022	Grant Read	peterborough paston parkwa	Uploaded successfully
# "c:\Users\arulr\harri\historicals\pontypool.csv"        pontypool
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	pontypool.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\port talbot.csv"        port talbot
# Jun 28, 2022	Grant Read	port talbot.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\porth cymer road.csv"        porth
# Jun 28, 2022	Grant Read	porth cymer road.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\redhill.csv"        redhill
# Jun 28, 2022	Grant Read	redhill.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\risca.csv"        risca
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	risca.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\ruislip.csv"        ruislip
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	ruislip.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\stevenage leisure.csv"        stevenage leisure
# Jun 28, 2022	Grant Read	stevenage leisure.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\stevenage roaring meg.csv"        stevenage roaring meg
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	stevenage roaring meg.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\swansea fforestfach.csv"        swansea fforestfach
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	swansea fforestfach.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\swansea morfa.csv"        swansea morfa
# Jun 28, 2022	Grant Read	swansea morfa.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\swansea morganite.csv"        swansea morganite
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	swansea morganite.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\swindon clive parade.csv"        swindon clive parade
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	swindon clive parade.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\swindon delta.csv"        swindon delta
# Jun 28, 2022	Grant Read	swindon delta.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\swindon greenbridge.csv"        swindon greenbridge
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	swindon greenbridge.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\swindon outlet centre.csv"        swindon outlet centre
# Jun 28, 2022	Grant Read	swindon outlet centre.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\talbot green.csv"        talbot
# Jun 28, 2022	Grant Read	talbot green.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\thorpe park.csv"        thorpe park
# Took too Long. Attempts: 1
# "c:\Users\arulr\harri\historicals\tooting.csv"        tooting
# Jun 28, 2022	Grant Read	tooting.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\uttoxeter.csv"        uttoxeter
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	uttoxeter.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\wembley.csv"        wembley
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	wembley.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\wimbledon.csv"        wimbledon
# Jun 28, 2022	Grant Read	wimbledon.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\wincanton.csv"        wincanton
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	wincanton.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\wisbeech.csv"        wisbech
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	wisbeech.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\wood green express.csv"        wood green express
# attempts: 3'
# '
# Jun 28, 2022	Grant Read	wood green express.csv	Uploaded successfully
# "c:\Users\arulr\harri\historicals\wood green restaurant.csv"        wood green restaurant
# Jun 28, 2022	Grant Read	wood green restaurant.csv	Uploaded successfully

# %%
# make sure you are on the dashboard page
def get_list_of_sites():
    driver.get('http://harristaging.com/dashboard')
    element = wait.until(EC.element_to_be_clickable(
        (By.XPATH, "//*[@id='top']/div/nav/ul[3]/li[6]/a/i")))
    element.click()
    wait.until(EC.element_to_be_clickable(
        (By.XPATH, "//*[@id='top']/div[2]/h-brands-list/div/div/div[1]")))
    element_blk = driver.find_elements(
        By.XPATH, "//h-brands-list//div[@class='locations-list-wrapper'][2]//div[@class='location-map-block']/following::div[1]")
    for ele in element_blk:
        driver.execute_script("""
        var ele = arguments[0];
        ele.parentNode.removeChild(ele);
        """, ele)
#    element_blk = driver.find_elements(By.XPATH,"//h-brands-list//div[@class='locations-list-wrapper'][2]//div[@class='location-map-block']")
#    for ele in element_blk:
#        driver.execute_script("""
#        var ele = arguments[0];
#        ele.parentNode.removeChild(ele);
#        """, ele)

    elems = driver.find_elements(
        By.XPATH, "//h-brands-list//div[@class='locations-list-wrapper'][2]//div[contains(@class,'brand-name')]")
    print(len(elems))
    sites = []
    for ele in elems:
        print(f"{ele.get_attribute('innerText')}")
        sites.extend(f"{ele.get_attribute('innerText')}".split('\n'))
    print(sites)
